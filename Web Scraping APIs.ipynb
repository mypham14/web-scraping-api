# %% [markdown]
# # Exchange Rates API
#
# ## Pulling data from public APIS - GET request

# %%
# Get exchange rates from https://exchangeratesapi.io/
API_KEY = '2a3862c4860db1647123f3d9a3dfe5fd'
base_url = "https://api.exchangeratesapi.io/v1/latest?access_key="+str(API_KEY)

# %% [markdown]
# ## Extracting data on currency exchange rates

# %%
# Send a GET request
import requests
response = requests.get(base_url)
# response

# %% [markdown]
# ## Investigating the response

# %%
response.ok
# Out:
# True

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"success":true,"timestamp":1731807376,"base":"EUR","date":"2024-11-17","rates":{"AED":3.873085,"AFN":71.98403,"ALL":98.091865,"AMD":410.865926,"ANG":1.906142,"AOA":961.670233,"ARS":1051.538092,"AUD":1.632295,"AWG":1.89276,"AZN":1.796773,"BAM":1.955638,"BBD":2.135523,"BDT":126.389518,"BGN":1.958718,"BHD":0.396967,"BIF":3123.440963,"BMD":1.054463,"BND":1.417882,"BOB":7.308394,"BRL":6.112667,"BSD":1.057612,"BTC":1.1683992e-5,"BTN":88.859931,"BWP":14.458801,"BYN":3.461213,"BYR":20667.465977,"BZD":2.131923,"CAD":1.486845,"CDF":3021.035587,"CHF":0.936297,"CLF":0.037463,"CLP":1028.384713,"CNY":7.626405,"CNH":7.630566,"COP":4744.106555,"CRC":538.255361,"CUC":1.054463,"CUP":27.943258,"CVE":110.255856,"CZK":25.271148,"DJF":188.334381,"DKK":7.463529,"DOP":63.724715,"DZD":140.438353,"EGP":51.981689,"ERN":15.816938,"ETB":128.080678,"EUR":1,"FJD":2.399904,"FKP":0.832305,"GBP":0.835681,"GEL":2.883997,"GGP":0.832305,"GHS":16.895599,"GIP":0.832305,"GMD":74.867216,"GNF":9114.244125,"GTQ":8.168323,"G
# ...

# %%
response.content
# Out:
# b'{"success":true,"timestamp":1731807376,"base":"EUR","date":"2024-11-17","rates":{"AED":3.873085,"AFN":71.98403,"ALL":98.091865,"AMD":410.865926,"ANG":1.906142,"AOA":961.670233,"ARS":1051.538092,"AUD":1.632295,"AWG":1.89276,"AZN":1.796773,"BAM":1.955638,"BBD":2.135523,"BDT":126.389518,"BGN":1.958718,"BHD":0.396967,"BIF":3123.440963,"BMD":1.054463,"BND":1.417882,"BOB":7.308394,"BRL":6.112667,"BSD":1.057612,"BTC":1.1683992e-5,"BTN":88.859931,"BWP":14.458801,"BYN":3.461213,"BYR":20667.465977,"BZD":2.131923,"CAD":1.486845,"CDF":3021.035587,"CHF":0.936297,"CLF":0.037463,"CLP":1028.384713,"CNY":7.626405,"CNH":7.630566,"COP":4744.106555,"CRC":538.255361,"CUC":1.054463,"CUP":27.943258,"CVE":110.255856,"CZK":25.271148,"DJF":188.334381,"DKK":7.463529,"DOP":63.724715,"DZD":140.438353,"EGP":51.981689,"ERN":15.816938,"ETB":128.080678,"EUR":1,"FJD":2.399904,"FKP":0.832305,"GBP":0.835681,"GEL":2.883997,"GGP":0.832305,"GHS":16.895599,"GIP":0.832305,"GMD":74.867216,"GNF":9114.244125,"GTQ":8.168323,"
# ...

# %% [markdown]
# ## Handling the JSON

# %%
response.json()
# Out:
# {'success': True,
#  'timestamp': 1731807376,
#  'base': 'EUR',
#  'date': '2024-11-17',
#  'rates': {'AED': 3.873085,
#   'AFN': 71.98403,
#   'ALL': 98.091865,
#   'AMD': 410.865926,
#   'ANG': 1.906142,
#   'AOA': 961.670233,
#   'ARS': 1051.538092,
#   'AUD': 1.632295,
#   'AWG': 1.89276,
#   'AZN': 1.796773,
#   'BAM': 1.955638,
#   'BBD': 2.135523,
#   'BDT': 126.389518,
#   'BGN': 1.958718,
#   'BHD': 0.396967,
#   'BIF': 3123.440963,
#   'BMD': 1.054463,
#   'BND': 1.417882,
#   'BOB': 7.308394,
#   'BRL': 6.112667,
#   'BSD': 1.057612,
#   'BTC': 1.1683992e-05,
#   'BTN': 88.859931,
#   'BWP': 14.458801,
#   'BYN': 3.461213,
#   'BYR': 20667.465977,
#   'BZD': 2.131923,
#   'CAD': 1.486845,
#   'CDF': 3021.035587,
#   'CHF': 0.936297,
#   'CLF': 0.037463,
#   'CLP': 1028.384713,
#   'CNY': 7.626405,
#   'CNH': 7.630566,
#   'COP': 4744.106555,
#   'CRC': 538.255361,
#   'CUC': 1.054463,
#   'CUP': 27.943258,
#   'CVE': 110.255856,
#   'CZK': 25.271148,
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# Convert Python object to JSON 
import json
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "success": true,
#     "timestamp": 1731807376,
#     "base": "EUR",
#     "date": "2024-11-17",
#     "rates": {
#         "AED": 3.873085,
#         "AFN": 71.98403,
#         "ALL": 98.091865,
#         "AMD": 410.865926,
#         "ANG": 1.906142,
#         "AOA": 961.670233,
#         "ARS": 1051.538092,
#         "AUD": 1.632295,
#         "AWG": 1.89276,
#         "AZN": 1.796773,
#         "BAM": 1.955638,
#         "BBD": 2.135523,
#         "BDT": 126.389518,
#         "BGN": 1.958718,
#         "BHD": 0.396967,
#         "BIF": 3123.440963,
#         "BMD": 1.054463,
#         "BND": 1.417882,
#         "BOB": 7.308394,
#         "BRL": 6.112667,
#         "BSD": 1.057612,
#         "BTC": 1.1683992e-05,
#         "BTN": 88.859931,
#         "BWP": 14.458801,
#         "BYN": 3.461213,
#         "BYR": 20667.465977,
#         "BZD": 2.131923,
#         "CAD": 1.486845,
#         "CDF": 3021.035587,
#         "CHF": 0.936297,
#         "CLF": 0.037463,
# ...

# %%
# View keys of the dict
response.json().keys()
# Out:
# dict_keys(['success', 'timestamp', 'base', 'date', 'rates'])

# %% [markdown]
# ## Incorporating parameters in the GET request

# %%
param_url = base_url + "&symbols=JPY,EUR"
param_url
# Out:
# 'https://api.exchangeratesapi.io/v1/latest?access_key=2a3862c4860db1647123f3d9a3dfe5fd&symbols=JPY,EUR'

# %%
response = requests.get(param_url)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'success': True,
#  'timestamp': 1731807376,
#  'base': 'EUR',
#  'date': '2024-11-17',
#  'rates': {'JPY': 162.746281, 'EUR': 1}}

# %%
data['base']
# Out:
# 'EUR'

# %%
data['date']
# Out:
# '2024-11-17'

# %%
data['rates']
# Out:
# {'JPY': 162.746281, 'EUR': 1}

# %%
param_url = base_url + "&symbols=JPY" + "&base=EUR"
param_url
# Out:
# 'https://api.exchangeratesapi.io/v1/latest?access_key=2a3862c4860db1647123f3d9a3dfe5fd&symbols=JPY&base=EUR'

# %%
data = requests.get(param_url).json()
data
# Out:
# {'success': True,
#  'timestamp': 1731807376,
#  'base': 'EUR',
#  'date': '2024-11-17',
#  'rates': {'JPY': 162.746281}}

# %%
eur_to_jpy = data['rates']['JPY']
eur_to_jpy
# Out:
# 162.746281

# %% [markdown]
# ## Obtaining historical exchange rates

# %%
base_url = "https://api.exchangeratesapi.io/v1/"

# %%
historical_url = base_url + "/2016-01-26" + "?access_key=" + str(API_KEY)
historical_url
# Out:
# 'https://api.exchangeratesapi.io/v1//2016-01-26?access_key=2a3862c4860db1647123f3d9a3dfe5fd'

# %%
resposne = requests.get(historical_url)
response.status_code
# Out:
# 200

# %%
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "success": true,
#     "timestamp": 1731807376,
#     "base": "EUR",
#     "date": "2024-11-17",
#     "rates": {
#         "JPY": 162.746281,
#         "EUR": 1
#     }
# }

# %% [markdown]
# ## Extracting data for a time period

# %%
time_period = base_url + "/timeseries" + "?access_key=" + str(API_KEY) + "&start_date=2017-04-26" + "&end_date=2018-04-26" + "&symbols=EUR"
time_period
# Out:
# 'https://api.exchangeratesapi.io/v1//timeseries?access_key=2a3862c4860db1647123f3d9a3dfe5fd&start_date=2017-04-26&end_date=2018-04-26&symbols=EUR'

# %%
response = requests.get(time_period)
response.status_code
# Out:
# 403

# %%
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "error": {
#         "code": "function_access_restricted",
#         "message": "Access Restricted - Your current Subscription Plan does not support this API Function."
#     }
# }

# %% [markdown]
# ## Testing te API response to incorrect input

# %%
invalid_url = base_url + "/2025-01-26" + "?access_key=" + str(API_KEY)
invalid_url
# Out:
# 'https://api.exchangeratesapi.io/v1//2025-01-26?access_key=2a3862c4860db1647123f3d9a3dfe5fd'

# %%
response = requests.get(invalid_url)
response.status_code
# Out:
# 400

# %%
data = response.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "error": {
#         "code": "invalid_date",
#         "message": "You have entered an invalid date. [Required format: date=YYYY-MM-DD]"
#     }
# }

# %% [markdown]
# ## Creating a simple currency converter

# %%
date = input("Please enter the date (in the format yyyy-mm-dd or 'latest': ")
base = input("Convert from (currency): ")
curr = input("Convert to (currency): ")
quan = float(input("How much {} do you want to convert: ".format(base)))

url = base_url + "/" + date + "?access_key=" + str(API_KEY) + "&base=" + base + "&symbols=" + curr
response = requests.get(url)

if (response.ok) is False:
    print("\nError {}: ".format(response.status_code))
    print(response.json()['error'])
else:
    data = response.json()
    rate = data['rates'][curr]
    result = quan*rate
    print("\n{0} {1} is equal to {2} {3}, based upon exchange rates on {4}".format(quan,base,result,curr,data['date']))
# Out:
# Please enter the date (in the format yyyy-mm-dd or 'latest':  2009-07-03
# Convert from (currency):  EUR
# Convert to (currency):  GBP
# How much EUR do you want to convert:  26
# 26.0 EUR is equal to 22.248668 GBP, based upon exchange rates on 2009-07-03

# %% [markdown]
# # iTunes Search API
#
# ## Passing parameters in the request

# %%
base_site = "https://itunes.apple.com/search"

# %%
url = base_site + "?term=the+beatles&country=us"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
r = requests.get(base_site, params={'term':'the beatles','country':'us'})
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the+beatles&country=us'

# %% [markdown]
# ## Investigating the output and parameters

# %%
info = r.json()
# print(json.dumps(info, indent=4))

# %%
info.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
# print(json.dumps(info['results'], indent=4))

# %%
info['resultCount']
# Out:
# 52

# %%
r = requests.get(base_site, params={'term':'the beatles','country':'us','limit':200})
r.ok
# Out:
# True

# %%
r.json()['resultCount']
# Out:
# 178

# %%
r = requests.get(base_site, params={'media':'hahaha','term':'alternative','country':'us'})
r.status_code
# Out:
# 400

# %%
r.json
# Out:
# <bound method Response.json of <Response [400]>>

# %% [markdown]
# ## References
#
# https://github.com/15Dkatz/official_joke_api
#
# https://sv443.net/jokeapi/v2/

# %% [markdown]
# ## Structuring and exporting the data

# %%
import pandas as pd

songs_df = pd.DataFrame(info['results'])
songs_df.head()
# Out:
#   wrapperType     artistId  collectionId                        artistName  \
# 0   audiobook  160778930.0  1.439484e+09                         Bob Spitz
# 1   audiobook    2037074.0  1.646009e+09                     Hunter Davies
# 2       track     157458.0  2.824953e+08                   Daniel Johnston
# 3       track          NaN  1.585883e+09  Joachim Rønning & Espen Sandberg
# 4       track    5621730.0  1.025317e+09                  Devendra Banhart
#
#                                 collectionName  \
# 0                       The Beatles (Abridged)
# 1                                  The Beatles
# 2                              Yip! Jump Music
# 3  Pirates Of The Caribbean 5-Movie Collection
# 4                                 Cripple Crow
#
#                         collectionCensoredName  \
# 0                       The Beatles (Abridged)
# 1                                  The Beatles
# 2                              Yip! Jump Music
# ...

# %%
# songs_df.to_csv("songs_info.csv)

# %%
# songs_df.to_excel("songs_info.xlsx)

# %% [markdown]
# ## Pagination

# %%
base_site = "https://jobs.github.com/positions.json"

# %%
# r = requests.get(base_site, params={'description':'data science','location':'los angeles'})
# r = requests.get("https://jobs.github.com/positions.json?description=api&location=new+york")
# r.status_code

# %%
# r.json()

# %%
# len(r.json())

# %% [markdown]
# ## The page parameter

# %%
# r = requests.get(base_site)
# r.ok

# %%
# r.json()

# %%
# len(r.json())

# %%
# r = requests.get(base_site, params={'page':2})
# r.status_code

# %%
# r.json()

# %%
# len(r.json())

# %%
# r = requests.get(base_site, params={'page':6})
# r.status_code

# %%
# r = requests.get(base_site, params={'page':10})
# r.status_code

# %%
# r.json()

# %% [markdown]
# ## Extracting results from multiple pages

# %%
# results = []

# for i in range(5):
#     r = requests.get(base_site, params={'page':i+1})

#     if len(r.json())==0:
#         break
#     else:
#         results.extend(r.json())

# %%
# len(results)

# %% [markdown]
# # BeautifulSoup
#
# ## Making a GET request

# %%
from bs4 import BeautifulSoup

base_site = "https://en.wikipedia.org/wiki/Music"

# %%
response = requests.get(base_site)
response
# Out:
# <Response [200]>

# %%
# Get html content
html = response.content
html[:100]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-la'

# %% [markdown]
# ## Making the soup

# %%
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# ## Exporting the html to a file

# %%
with open("Wiki_response.html",'wb') as file:
    file.write(soup.prettify('utf-8'))

# %% [markdown]
# ## Searching and navigating the html tree

# %%
# Searching -find() and find_all()
# soup

# %%
soup.find('head')
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Music - Wikipedia</title>
# ...

# %%
type(soup.find('video'))
# Out:
# NoneType

# %%
soup.find('a') # returns the first result only, if no result found: return None
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
# Show all results, if no result found: return empty list
links = soup.find_all('a')
# links

# %%
# Check if it's a list
isinstance(links,list)
# Out:
# True

# %%
soup.find_all('video')
# Out:
# []

# %%
len(links)
# Out:
# 2499

# %%
# Find the body text
table = soup.find('tbody')
table
# Out:
# <tbody><tr><td class="sidebar-pretitle" style="background:antiquewhite;">Part of <a href="/wiki/Category:Performing_arts" title="Category:Performing arts">a series</a> on</td></tr><tr><th class="sidebar-title-with-pretitle" style="background:antiquewhite;;display:block;margin-bottom:0.4em;"><a href="/wiki/Performing_arts" title="Performing arts">Performing arts</a></th></tr><tr><td class="sidebar-content hlist">
# <ul><li><a href="/wiki/Acrobatics" title="Acrobatics">Acrobatics</a></li>
# <li><a href="/wiki/Ballet" title="Ballet">Ballet</a></li>
# <li><a href="/wiki/List_of_circus_skills" title="List of circus skills">Circus skills</a></li>
# <li><a href="/wiki/Clown" title="Clown">Clown</a></li>
# <li><a href="/wiki/Dance" title="Dance">Dance</a></li>
# <li><a href="/wiki/Gymnastics" title="Gymnastics">Gymnastics</a></li>
# <li><a href="/wiki/Magic_(illusion)" title="Magic (illusion)">Magic</a></li>
# <li><a href="/wiki/Mime_artist" title="Mime artist">Mime</a></li>
# ...

# %%
type(table)
# Out:
# bs4.element.Tag

# %%
# Find all tags
table.find_all('td')
# Out:
# [<td class="sidebar-pretitle" style="background:antiquewhite;">Part of <a href="/wiki/Category:Performing_arts" title="Category:Performing arts">a series</a> on</td>,
#  <td class="sidebar-content hlist">
#  <ul><li><a href="/wiki/Acrobatics" title="Acrobatics">Acrobatics</a></li>
#  <li><a href="/wiki/Ballet" title="Ballet">Ballet</a></li>
#  <li><a href="/wiki/List_of_circus_skills" title="List of circus skills">Circus skills</a></li>
#  <li><a href="/wiki/Clown" title="Clown">Clown</a></li>
#  <li><a href="/wiki/Dance" title="Dance">Dance</a></li>
#  <li><a href="/wiki/Gymnastics" title="Gymnastics">Gymnastics</a></li>
#  <li><a href="/wiki/Magic_(illusion)" title="Magic (illusion)">Magic</a></li>
#  <li><a href="/wiki/Mime_artist" title="Mime artist">Mime</a></li>
#  <li><a class="mw-selflink selflink">Music</a></li>
#  <li><a href="/wiki/Opera" title="Opera">Opera</a></li>
# ...

# %%
len(table.find_all('td'))
# Out:
# 3

# %% [markdown]
# ## Navigating the tree

# %%
table.contents
# Out:
# [<tr><td class="sidebar-pretitle" style="background:antiquewhite;">Part of <a href="/wiki/Category:Performing_arts" title="Category:Performing arts">a series</a> on</td></tr>,
#  <tr><th class="sidebar-title-with-pretitle" style="background:antiquewhite;;display:block;margin-bottom:0.4em;"><a href="/wiki/Performing_arts" title="Performing arts">Performing arts</a></th></tr>,
#  <tr><td class="sidebar-content hlist">
#  <ul><li><a href="/wiki/Acrobatics" title="Acrobatics">Acrobatics</a></li>
#  <li><a href="/wiki/Ballet" title="Ballet">Ballet</a></li>
#  <li><a href="/wiki/List_of_circus_skills" title="List of circus skills">Circus skills</a></li>
#  <li><a href="/wiki/Clown" title="Clown">Clown</a></li>
#  <li><a href="/wiki/Dance" title="Dance">Dance</a></li>
#  <li><a href="/wiki/Gymnastics" title="Gymnastics">Gymnastics</a></li>
#  <li><a href="/wiki/Magic_(illusion)" title="Magic (illusion)">Magic</a></li>
#  <li><a href="/wiki/Mime_artist" title="Mime artist">Mime</a></li>
# ...

# %%
len(table.contents)
# Out:
# 4

# %%
table.parent
# Out:
# <table class="sidebar nomobile nowraplinks"><tbody><tr><td class="sidebar-pretitle" style="background:antiquewhite;">Part of <a href="/wiki/Category:Performing_arts" title="Category:Performing arts">a series</a> on</td></tr><tr><th class="sidebar-title-with-pretitle" style="background:antiquewhite;;display:block;margin-bottom:0.4em;"><a href="/wiki/Performing_arts" title="Performing arts">Performing arts</a></th></tr><tr><td class="sidebar-content hlist">
# <ul><li><a href="/wiki/Acrobatics" title="Acrobatics">Acrobatics</a></li>
# <li><a href="/wiki/Ballet" title="Ballet">Ballet</a></li>
# <li><a href="/wiki/List_of_circus_skills" title="List of circus skills">Circus skills</a></li>
# <li><a href="/wiki/Clown" title="Clown">Clown</a></li>
# <li><a href="/wiki/Dance" title="Dance">Dance</a></li>
# <li><a href="/wiki/Gymnastics" title="Gymnastics">Gymnastics</a></li>
# <li><a href="/wiki/Magic_(illusion)" title="Magic (illusion)">Magic</a></li>
# ...

# %%
table.parent.parent
# Out:
# <div class="mw-content-ltr mw-parser-output" dir="ltr" lang="en"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Form of art using sound</div>
# <style data-mw-deduplicate="TemplateStyles:r1236090951">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}@media print{body.ns-0 .mw-parser-output .hatnote{display:none!important}}</style><div class="hatnote navigation-not-searchable" role="note">For other uses, see <a class="mw-disambig" href="/wiki/Music_(disambiguation)" title="Music (disambiguation)">Music (disambiguation)</a>.</div>
# <p class="mw-empty-elt">
# </p>
# ...

# %% [markdown]
# ## Searching by attributes

# %%
soup.find('div', id = 'siteSub')
# Out:
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>

# %% [markdown]
# ## Passing attributes as function parameters

# %%
soup.find_all('a', class_='mw-jump-link')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>]

# %%
soup.find('a', class_='mw-jump-link', href='#p-search')

# %% [markdown]
# ## Placing attributes in a dictionary

# %%
soup.find('a', attrs={'class':'mw-jump-link', 'href':'#p-search'})

# %%
soup.find('div',{'id':'footer'})

# %% [markdown]
# ## Extracting data from the html tree

# %%
a = soup.find('a', class_='mw-jump-link')
a
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
a.name
# Out:
# 'a'

# %% [markdown]
# ## Getting the attribute value

# %%
a['class']
# Out:
# ['mw-jump-link']

# %%
a['href']
# Out:
# '#bodyContent'

# %%
a.get('href')
# Out:
# '#bodyContent'

# %%
a.get('class')
# Out:
# ['mw-jump-link']

# %%
# Differences between these methods manifest is when the key is missing
a['id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[209], line 2
#       1 # Differences between these methods manifest is when the key is missing
# ----> 2 a['id']
#
# File ~\anaconda3\lib\site-packages\bs4\element.py:1573, in Tag.__getitem__(self, key)
#    1570 def __getitem__(self, key):
#    1571     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1572     and throws an exception if it's not there."""
# -> 1573     return self.attrs[key]
#
# KeyError: 'id'

# %%
a.get('id')

# %%
repr(a.get('id'))
# Out:
# 'None'

# %%
a.attrs
# Out:
# {'class': ['mw-jump-link'], 'href': '#bodyContent'}

# %% [markdown]
# ## Extracting the text

# %%
a.string
# Out:
# 'Jump to content'

# %%
a.text
# Out:
# 'Jump to content'

# %% [markdown]
# ## When the element contains more than one distinct string

# %%
p = soup.find_all('p')[1]
p
# Out:
# <p><b>Music</b> is the arrangement of <a href="/wiki/Sound" title="Sound">sound</a> to create some combination of <a href="/wiki/Musical_form" title="Musical form">form</a>, <a href="/wiki/Harmony" title="Harmony">harmony</a>, <a href="/wiki/Melody" title="Melody">melody</a>, <a href="/wiki/Rhythm" title="Rhythm">rhythm</a>, or otherwise <a href="/wiki/Musical_expression" title="Musical expression">expressive content</a>.<sup class="reference" id="cite_ref-FOOTNOTE''OED''§&amp;nbsp;1_1-0"><a href="#cite_note-FOOTNOTE''OED''§&amp;nbsp;1-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-FOOTNOTE''AHD''§&amp;nbsp;1_2-0"><a href="#cite_note-FOOTNOTE''AHD''§&amp;nbsp;1-2"><span class="cite-bracket">[</span>2<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-FOOTNOTEEpperson2022§_para._1_3-0"><a href="#cite_note-FOOTNOTEEpperson2022§_para._1-3"><span class="cite-bracket">[</span>3<span class
# ...

# %%
p.text
# Out:
# 'Music is the arrangement of sound to create some combination of form, harmony, melody, rhythm, or otherwise expressive content.[1][2][3] Music is generally agreed to be a cultural universal that is present in all human societies.[4] Definitions of music vary widely in substance and approach.[5] While scholars agree that music is defined by a small number of specific elements, there is no consensus as to what these necessary elements are.[6] Music is often characterized as a highly versatile medium for expressing human creativity.[7] Diverse activities are involved in the creation of music, and are often divided into categories of composition, improvisation, and performance.[8] Music may be performed using a wide variety of musical instruments, including the human voice. It can also be composed, sequenced, or otherwise produced to be indirectly played mechanically or electronically, such as via a music box, barrel organ, or digital audio workstation software on a computer.\n'

# %%
p.string

# %%
repr(p.string)
# Out:
# 'None'

# %%
p.parent
# Out:
# <div class="mw-content-ltr mw-parser-output" dir="ltr" lang="en"><div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Form of art using sound</div>
# <style data-mw-deduplicate="TemplateStyles:r1236090951">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}@media print{body.ns-0 .mw-parser-output .hatnote{display:none!important}}</style><div class="hatnote navigation-not-searchable" role="note">For other uses, see <a class="mw-disambig" href="/wiki/Music_(disambiguation)" title="Music (disambiguation)">Music (disambiguation)</a>.</div>
# <p class="mw-empty-elt">
# </p>
# ...

# %%
print(p.parent.text)
# Out:
# Form of art using sound
# For other uses, see Music (disambiguation).
#
#
# Grooved side of the Voyager Golden Record launched along the Voyager probes to space, which feature music from around the world
# Part of a series onPerforming arts
# Acrobatics
# Ballet
# Circus skills
# Clown
# Dance
# Gymnastics
# Magic
# Mime
# Music
# Opera
# Professional wrestling
# Puppetry
# Speech
# Stand-up comedy
# Street performance
# Theatre
# Ventriloquism
# vte
# ...

# %%
print(soup.text)
# Out:
# Music - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1
# Etymology and terminology
#
#
#
#
#
#
#
#
# 2
# History
#
#
#
#
# Toggle History subsection
#
#
#
#
#
# 2.1
# Origins and prehistory
#
#
#
#
#
# ...

# %%
# strings and stripped strings
for s in p.strings:
    print(repr(s))
# Out:
# 'Music'
# ' is the arrangement of '
# 'sound'
# ' to create some combination of '
# 'form'
# ', '
# 'harmony'
# ', '
# 'melody'
# ', '
# 'rhythm'
# ', or otherwise '
# 'expressive content'
# '.'
# '['
# '1'
# ']'
# '['
# '2'
# ']'
# '['
# '3'
# ']'
# ' Music is generally agreed to be a '
# 'cultural universal'
# ' that is present in all human societies.'
# '['
# '4'
# ']'
# ' '
# 'Definitions of music'
# ' vary widely in substance and approach.'
# '['
# '5'
# ']'
# ' While scholars agree that music is defined by a small number of '
# 'specific elements'
# ', there is no consensus as to what these necessary elements are.'
# '['
# '6'
# ']'
# ' Music is often characterized as a highly versatile medium for expressing human '
# 'creativity'
# '.'
# '['
# '7'
# ']'
# ' Diverse activities are involved in the creation of music, and are often divided into categories of '
# 'composition'
# ', '
# 'improvisation'
# ', and '
# 'performance'
# '.'
# '['
# '8'
# ']'
# ...

# %%
for s in p.stripped_strings:
    print(repr(s))
# Out:
# 'Music'
# 'is the arrangement of'
# 'sound'
# 'to create some combination of'
# 'form'
# ','
# 'harmony'
# ','
# 'melody'
# ','
# 'rhythm'
# ', or otherwise'
# 'expressive content'
# '.'
# '['
# '1'
# ']'
# '['
# '2'
# ']'
# '['
# '3'
# ']'
# 'Music is generally agreed to be a'
# 'cultural universal'
# 'that is present in all human societies.'
# '['
# '4'
# ']'
# 'Definitions of music'
# 'vary widely in substance and approach.'
# '['
# '5'
# ']'
# 'While scholars agree that music is defined by a small number of'
# 'specific elements'
# ', there is no consensus as to what these necessary elements are.'
# '['
# '6'
# ']'
# 'Music is often characterized as a highly versatile medium for expressing human'
# 'creativity'
# '.'
# '['
# '7'
# ']'
# 'Diverse activities are involved in the creation of music, and are often divided into categories of'
# 'composition'
# ','
# 'improvisation'
# ', and'
# 'performance'
# '.'
# '['
# '8'
# ']'
# 'Music may be performed using a wide variety of'
# ...
